# %%
import pickle

# %%
load_model = pickle.load(open('../pickles/pp_pred_pipe', 'rb'))

# %%
import pandas as pd
import numpy as np

# %%
defaulters = pd.read_csv('/Users/isislim/Documents/LeWagon/defaulter_data_13364.csv')
defaulters.head()
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
# 1           1  6ea315e6f219bc513964121907331f96e5b194127ebee3...  2017-09-10
# 2           2  6f105fec0ab833183a6a7aa3e39e79a6adf88a7cabe9df...  2017-03-26
# 3           3  6f105fec0ab833183a6a7aa3e39e79a6adf88a7cabe9df...  2017-04-26
# 4           4  6f105fec0ab833183a6a7aa3e39e79a6adf88a7cabe9df...  2017-05-26
#
#         P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.524390  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
# 1  0.463367  0.003464  0.024714  0.818614  0.504045  0.218091  0.001362  ...
# 2  0.463461  0.093902  0.008374  0.818932  0.501653  0.240602  0.002078  ...
# 3  0.442675  0.002785  0.008545  1.005278  0.008112  0.257985  0.008379  ...
# 4  0.471713  0.095840  0.011414  0.817346  0.508451  0.154248  0.000736  ...
#
# ...

# %%
test_row = defaulters.iloc[[0]]
test_row
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#    D_136  D_137  D_138     D_139     D_140    D_141     D_142     D_143  \
# 0    NaN    NaN    NaN  1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
load_model.predict(test_row)[0]
# Out:
# 1

# %%
pred_proba = load_model.predict_proba(test_row)

# %%
pred_proba[0][1]
# Out:
# 0.6950514069152902

# %%
test_row.to_csv('test_row.csv'b)

# %%
test_dict = test_row.to_dict(orient='records')[0]
test_dict
# Out:
# {'Unnamed: 0': 0,
#  'customer_ID': '6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339',
#  'S_2': '2017-04-29',
#  'P_2': 0.5243904931830153,
#  'D_39': 0.3313523183745179,
#  'B_1': 0.0226474075652035,
#  'B_2': 1.0098138176705274,
#  'R_1': 0.0094418612623092,
#  'S_3': 0.3013753140016364,
#  'D_41': 0.0078785629732383,
#  'B_3': 0.0258205059627975,
#  'D_42': 0.1442666865165377,
#  'D_43': 0.2719021428514478,
#  'D_44': nan,
#  'B_4': 0.0283137155569896,
#  'D_45': 0.0181600179345101,
#  'B_5': 0.042604957206283,
#  'R_2': 0.0076086225667935,
#  'D_46': 0.4423322496494613,
#  'D_47': 0.5640947570546344,
#  'D_48': nan,
#  'D_49': nan,
#  'B_6': 0.1141169198300304,
#  'B_7': 0.0364595248656915,
#  'B_8': 1.001206164416357,
#  'D_50': nan,
#  'D_51': 0.0055727585123258,
#  'B_9': 0.2995098902026097,
#  'R_3': 0.5078069824461213,
#  'D_52': 0.0065321521685339,
#  'P_3': 0.9704147394434446,
#  'B_10': 0.1931363807984167,
#  'D_53': nan,
#  'S_5': 0.0497382032113571,
# ...

# %%
new_array = pd.DataFrame.from_dict(test_dict,orient='index').transpose()
new_array
# Out:
#   Unnamed: 0                                        customer_ID         S_2  \
# 0          0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#   D_136 D_137 D_138     D_139     D_140    D_141     D_142     D_143  \
# 0   NaN   NaN   NaN  1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
import requests

# %%
test = pd.read_csv('../AMEX_default_prediction/api/test_row.csv',index_col=0)
test
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#    D_136  D_137  D_138     D_139     D_140    D_141     D_142     D_143  \
# 0    NaN    NaN    NaN  1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
test
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#    D_136  D_137  D_138     D_139     D_140    D_141     D_142     D_143  \
# 0    NaN    NaN    NaN  1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
url = 'http://localhost:8000/predict'
params = pd.read_csv('../AMEX_default_prediction/api/test_row.csv').to_dict(orient='records')[0]
response = requests.get(url, params=params)
response.json()
# Out:
# {'detail': [{'loc': ['query', 'params'],
#    'msg': 'field required',
#    'type': 'value_error.missing'}]}

# %%
params = pd.read_csv('../AMEX_default_prediction/api/test_row.csv').fillna('').to_dict(orient='records')[0]
params
# Out:
# {'Unnamed: 0.1': 0,
#  'Unnamed: 0': 0,
#  'customer_ID': '6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339',
#  'S_2': '2017-04-29',
#  'P_2': 0.5243904931830153,
#  'D_39': 0.3313523183745179,
#  'B_1': 0.0226474075652035,
#  'B_2': 1.0098138176705274,
#  'R_1': 0.0094418612623092,
#  'S_3': 0.3013753140016364,
#  'D_41': 0.0078785629732383,
#  'B_3': 0.0258205059627975,
#  'D_42': 0.1442666865165377,
#  'D_43': 0.2719021428514478,
#  'D_44': '',
#  'B_4': 0.0283137155569896,
#  'D_45': 0.0181600179345101,
#  'B_5': 0.042604957206283,
#  'R_2': 0.0076086225667935,
#  'D_46': 0.4423322496494613,
#  'D_47': 0.5640947570546344,
#  'D_48': '',
#  'D_49': '',
#  'B_6': 0.1141169198300304,
#  'B_7': 0.0364595248656915,
#  'B_8': 1.001206164416357,
#  'D_50': '',
#  'D_51': 0.0055727585123258,
#  'B_9': 0.2995098902026097,
#  'R_3': 0.5078069824461213,
#  'D_52': 0.0065321521685339,
#  'P_3': 0.9704147394434446,
#  'B_10': 0.1931363807984167,
#  'D_53': '',
# ...

# %%
url = 'http://localhost:8000/predict'
params = test.to_dict(orient='records')[0]
response = requests.get(url, params=params)
response.json()
# Out:
# {'detail': [{'loc': ['query', 'params'],
#    'msg': 'field required',
#    'type': 'value_error.missing'}]}

# %%
params = test.to_dict(orient='records')[0]

# %%
params
# Out:
# {'Unnamed: 0': 0,
#  'customer_ID': '6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339',
#  'S_2': '2017-04-29',
#  'P_2': 0.5243904931830153,
#  'D_39': 0.3313523183745179,
#  'B_1': 0.0226474075652035,
#  'B_2': 1.0098138176705274,
#  'R_1': 0.0094418612623092,
#  'S_3': 0.3013753140016364,
#  'D_41': 0.0078785629732383,
#  'B_3': 0.0258205059627975,
#  'D_42': 0.1442666865165377,
#  'D_43': 0.2719021428514478,
#  'D_44': nan,
#  'B_4': 0.0283137155569896,
#  'D_45': 0.0181600179345101,
#  'B_5': 0.042604957206283,
#  'R_2': 0.0076086225667935,
#  'D_46': 0.4423322496494613,
#  'D_47': 0.5640947570546344,
#  'D_48': nan,
#  'D_49': nan,
#  'B_6': 0.1141169198300304,
#  'B_7': 0.0364595248656915,
#  'B_8': 1.001206164416357,
#  'D_50': nan,
#  'D_51': 0.0055727585123258,
#  'B_9': 0.2995098902026097,
#  'R_3': 0.5078069824461213,
#  'D_52': 0.0065321521685339,
#  'P_3': 0.9704147394434446,
#  'B_10': 0.1931363807984167,
#  'D_53': nan,
#  'S_5': 0.0497382032113571,
# ...

# %%
X_pred = pd.DataFrame.from_dict(params, orient="index").transpose().replace('',np.nan)

# %%
X_pred
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
#
#                                          customer_ID         S_2      P_2  \
# 0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29  0.52439
#
#        D_39       B_1       B_2       R_1       S_3  ...  D_136  D_137  D_138  \
# 0  0.331352  0.022647  1.009814  0.009442  0.301375  ...    NaN    NaN    NaN
#
#       D_139     D_140    D_141     D_142     D_143     D_144    D_145
# 0  1.008062  0.003595  0.87448  0.090184  1.001811  0.004446  0.36538
#
# [1 rows x 192 columns]

# %%
X_pred.fillna('')
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#    D_136  D_137  D_138     D_139     D_140    D_141     D_142     D_143  \
# 0                       1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
data2 = pd.read_csv('../AMEX_default_prediction/api/test_row.csv',index_col=0).fillna('').to_dict(orient='records')[0]
data2
# Out:
# {'Unnamed: 0': 0,
#  'customer_ID': '6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339',
#  'S_2': '2017-04-29',
#  'P_2': 0.5243904931830153,
#  'D_39': 0.3313523183745179,
#  'B_1': 0.0226474075652035,
#  'B_2': 1.0098138176705274,
#  'R_1': 0.0094418612623092,
#  'S_3': 0.3013753140016364,
#  'D_41': 0.0078785629732383,
#  'B_3': 0.0258205059627975,
#  'D_42': 0.1442666865165377,
#  'D_43': 0.2719021428514478,
#  'D_44': '',
#  'B_4': 0.0283137155569896,
#  'D_45': 0.0181600179345101,
#  'B_5': 0.042604957206283,
#  'R_2': 0.0076086225667935,
#  'D_46': 0.4423322496494613,
#  'D_47': 0.5640947570546344,
#  'D_48': '',
#  'D_49': '',
#  'B_6': 0.1141169198300304,
#  'B_7': 0.0364595248656915,
#  'B_8': 1.001206164416357,
#  'D_50': '',
#  'D_51': 0.0055727585123258,
#  'B_9': 0.2995098902026097,
#  'R_3': 0.5078069824461213,
#  'D_52': 0.0065321521685339,
#  'P_3': 0.9704147394434446,
#  'B_10': 0.1931363807984167,
#  'D_53': '',
#  'S_5': 0.0497382032113571,
# ...

# %%
import json

# %%
params = {"data": json.dumps(data2)}
params
# Out:
# {'data': '{"Unnamed: 0": 0, "customer_ID": "6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339", "S_2": "2017-04-29", "P_2": 0.5243904931830153, "D_39": 0.3313523183745179, "B_1": 0.0226474075652035, "B_2": 1.0098138176705274, "R_1": 0.0094418612623092, "S_3": 0.3013753140016364, "D_41": 0.0078785629732383, "B_3": 0.0258205059627975, "D_42": 0.1442666865165377, "D_43": 0.2719021428514478, "D_44": "", "B_4": 0.0283137155569896, "D_45": 0.0181600179345101, "B_5": 0.042604957206283, "R_2": 0.0076086225667935, "D_46": 0.4423322496494613, "D_47": 0.5640947570546344, "D_48": "", "D_49": "", "B_6": 0.1141169198300304, "B_7": 0.0364595248656915, "B_8": 1.001206164416357, "D_50": "", "D_51": 0.0055727585123258, "B_9": 0.2995098902026097, "R_3": 0.5078069824461213, "D_52": 0.0065321521685339, "P_3": 0.9704147394434446, "B_10": 0.1931363807984167, "D_53": "", "S_5": 0.0497382032113571, "B_11": 0.0170887078387576, "S_6": 6.264821241336181e-06, "D_54": 1.003239737456082, "R_4": 0.00
# ...

# %%
param_data = json.loads(params['data'])
param_data
# Out:
# {'Unnamed: 0': 0,
#  'customer_ID': '6ba461c93869797c49b0f34c29274e50915466eda02a82fde4aa2c73c3924339',
#  'S_2': '2017-04-29',
#  'P_2': 0.5243904931830153,
#  'D_39': 0.3313523183745179,
#  'B_1': 0.0226474075652035,
#  'B_2': 1.0098138176705274,
#  'R_1': 0.0094418612623092,
#  'S_3': 0.3013753140016364,
#  'D_41': 0.0078785629732383,
#  'B_3': 0.0258205059627975,
#  'D_42': 0.1442666865165377,
#  'D_43': 0.2719021428514478,
#  'D_44': '',
#  'B_4': 0.0283137155569896,
#  'D_45': 0.0181600179345101,
#  'B_5': 0.042604957206283,
#  'R_2': 0.0076086225667935,
#  'D_46': 0.4423322496494613,
#  'D_47': 0.5640947570546344,
#  'D_48': '',
#  'D_49': '',
#  'B_6': 0.1141169198300304,
#  'B_7': 0.0364595248656915,
#  'B_8': 1.001206164416357,
#  'D_50': '',
#  'D_51': 0.0055727585123258,
#  'B_9': 0.2995098902026097,
#  'R_3': 0.5078069824461213,
#  'D_52': 0.0065321521685339,
#  'P_3': 0.9704147394434446,
#  'B_10': 0.1931363807984167,
#  'D_53': '',
#  'S_5': 0.0497382032113571,
# ...

# %%
X_pred = pd.DataFrame(param_data,index=[0]).replace('',np.nan)
X_pred
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  6ba461c93869797c49b0f34c29274e50915466eda02a82...  2017-04-29
#
#        P_2      D_39       B_1       B_2       R_1       S_3      D_41  ...  \
# 0  0.52439  0.331352  0.022647  1.009814  0.009442  0.301375  0.007879  ...
#
#    D_136  D_137  D_138     D_139     D_140    D_141     D_142     D_143  \
# 0    NaN    NaN    NaN  1.008062  0.003595  0.87448  0.090184  1.001811
#
#       D_144    D_145
# 0  0.004446  0.36538
#
# [1 rows x 191 columns]

# %%
d = {"value1": 0, "value2": 3, "value3": 3}

# %%
p = {"data": json.dumps(d)}
p
# Out:
# {'data': '{"value1": 0, "value2": 3, "value3": 3}'}

# %%
def test(data):
    dict_data = json.loads(data['data'])
    return dict_data

# %%
test_d = test(p)

# %%
test_d
# Out:
# {'value1': 0, 'value2': 3, 'value3': 3}

# %%
X_pred = pd.DataFrame({'key':"2013-07-06 17:18:00",
                'pickup_datetime':'data',
                'pickup_longitude':0}, index=[0])

# %%
X_pred = pd.DataFrame(test_d,index=[0])
X_pred
# Out:
#    value1  value2  value3
# 0       0       3       3
