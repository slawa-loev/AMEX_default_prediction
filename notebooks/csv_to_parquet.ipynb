# %% [markdown]
# # Converting csv to parquet

# %%
import pandas as pd
import numpy as np

from google.cloud import bigquery
from google.oauth2 import service_account

# %% [markdown]
# ## Test dataset

# %%
payer_small = pd.read_csv('/Users/isislim/Documents/LeWagon/payer_data_41940.csv', index_col=[0])
payer_small.shape
# Out:
# (41940, 190)

# %%
defaulter_small = pd.read_csv('/Users/isislim/Documents/LeWagon/defaulter_data_13364.csv', index_col=[0])
defaulter_small.shape

# %%
pd.set_option('display.max_rows', 500)
payer_small.dtypes
# Out:
# customer_ID     object
# S_2             object
# P_2            float64
# D_39           float64
# B_1            float64
# B_2            float64
# R_1            float64
# S_3            float64
# D_41           float64
# B_3            float64
# D_42           float64
# D_43           float64
# D_44           float64
# B_4            float64
# D_45           float64
# B_5            float64
# R_2            float64
# D_46           float64
# D_47           float64
# D_48           float64
# D_49           float64
# B_6            float64
# B_7            float64
# B_8            float64
# D_50           float64
# D_51           float64
# B_9            float64
# R_3            float64
# D_52           float64
# P_3            float64
# B_10           float64
# D_53           float64
# S_5            float64
# B_11           float64
# S_6            float64
# D_54           float64
# R_4            float64
# S_7            float64
# B_12           float64
# S_8            float64
# D_55           float64
# D_56           float64
# B_13           float64
# R_5            float64
# D_58           float64
# S_9            float64
# B_14           float64
# D_59           float64
# D_60           float64
# D_61           float64
# B_15           float64
# S_11           float64
# D_62           float64
# D_63            object
# D_64            object
# D_65           float64
# B_16           float64
# B_17           float64
# B_18           float64
# B_19           float64
# D_66           float64
# B_20           float64
# D_68           float64
# S_12           float64
# R_6            float64
# S_13           float64
# B_21           float64
# D_69           float64
# B_22           float64
# D_70           float64
# D_71           float64
# D_72           float64
# S_15           float64
# B_23           float64
# D_73           float64
# P_4            float64
# D_74           float64
# D_75           float64
# D_76           float64
# B_24           float64
# R_7            float64
# D_77           float64
# B_25           float64
# B_26           float64
# D_78           float64
# D_79           float64
# R_8            float64
# R_9            float64
# S_16           float64
# D_80           float64
# R_10           float64
# R_11           float64
# B_27           float64
# D_81           float64
# D_82           float64
# S_17           float64
# R_12           float64
# B_28           float64
# R_13           float64
# D_83           float64
# R_14           float64
# R_15           float64
# D_84           float64
# R_16           float64
# B_29           float64
# B_30           float64
# S_18           float64
# D_86           float64
# D_87           float64
# R_17           float64
# R_18           float64
# D_88           float64
# B_31             int64
# S_19           float64
# R_19           float64
# B_32           float64
# S_20           float64
# R_20           float64
# R_21           float64
# B_33           float64
# D_89           float64
# R_22           float64
# R_23           float64
# D_91           float64
# D_92           float64
# D_93           float64
# D_94           float64
# R_24           float64
# R_25           float64
# D_96           float64
# S_22           float64
# S_23           float64
# S_24           float64
# S_25           float64
# S_26           float64
# D_102          float64
# D_103          float64
# D_104          float64
# D_105          float64
# D_106          float64
# D_107          float64
# B_36           float64
# B_37           float64
# R_26           float64
# R_27           float64
# B_38           float64
# D_108          float64
# D_109          float64
# D_110          float64
# D_111          float64
# B_39           float64
# D_112          float64
# B_40           float64
# S_27           float64
# D_113          float64
# D_114          float64
# D_115          float64
# D_116          float64
# D_117          float64
# D_118          float64
# D_119          float64
# D_120          float64
# D_121          float64
# D_122          float64
# D_123          float64
# D_124          float64
# D_125          float64
# D_126          float64
# D_127          float64
# D_128          float64
# D_129          float64
# B_41           float64
# B_42           float64
# D_130          float64
# D_131          float64
# D_132          float64
# D_133          float64
# R_28           float64
# D_134          float64
# D_135          float64
# D_136          float64
# D_137          float64
# D_138          float64
# D_139          float64
# D_140          float64
# D_141          float64
# D_142          float64
# D_143          float64
# D_144          float64
# D_145          float64
# dtype: object

# %%
def compress_datatypes(df):
    input_size = df.memory_usage(index=True).sum()/ 1024
    print("new dataframe size: ", round(input_size,2), 'kB')
    
    in_size = df.memory_usage(index=True).sum()
    
    for type in ["float", "integer"]:
        l_cols = list(df.select_dtypes(include=type))
        for col in l_cols:
            df[col] = pd.to_numeric(df[col], downcast=type)
    out_size = df.memory_usage(index=True).sum()
    ratio = (1 - round(out_size / in_size, 2)) * 100
    
    print("optimized size by {} %".format(round(ratio,2)))
    print("new dataframe size: ", round(out_size / 1024,2), " kB")

    return df

# %%
payer_small_compress = compress_datatypes(payer_small)
# Out:
# new dataframe size:  62582.34 kB
# optimized size by 49.0 %
# new dataframe size:  31987.44  kB

# %%
payer_small_compress.dtypes

# %%
payer_small.to_parquet('/Users/isislim/Documents/LeWagon/project_pitch/payer_small.parquet')

# %%
payer_parquet = pd.read_csv('/Users/isislim/Documents/LeWagon/project_pitch/payer_small.csv')
payer_parquet.dtypes
# Out:
# Unnamed: 0       int64
# customer_ID     object
# S_2             object
# P_2            float64
# D_39           float64
# B_1            float64
# B_2            float64
# R_1            float64
# S_3            float64
# D_41           float64
# B_3            float64
# D_42           float64
# D_43           float64
# D_44           float64
# B_4            float64
# D_45           float64
# B_5            float64
# R_2            float64
# D_46           float64
# D_47           float64
# D_48           float64
# D_49           float64
# B_6            float64
# B_7            float64
# B_8            float64
# D_50           float64
# D_51           float64
# B_9            float64
# R_3            float64
# D_52           float64
# P_3            float64
# B_10           float64
# D_53           float64
# S_5            float64
# B_11           float64
# S_6            float64
# D_54           float64
# R_4            float64
# S_7            float64
# B_12           float64
# S_8            float64
# D_55           float64
# D_56           float64
# B_13           float64
# R_5            float64
# D_58           float64
# S_9            float64
# B_14           float64
# D_59           float64
# D_60           float64
# D_61           float64
# B_15           float64
# S_11           float64
# D_62           float64
# D_63            object
# D_64            object
# D_65           float64
# B_16           float64
# B_17           float64
# B_18           float64
# B_19           float64
# D_66           float64
# B_20           float64
# D_68           float64
# S_12           float64
# R_6            float64
# S_13           float64
# B_21           float64
# D_69           float64
# B_22           float64
# D_70           float64
# D_71           float64
# D_72           float64
# S_15           float64
# B_23           float64
# D_73           float64
# P_4            float64
# D_74           float64
# D_75           float64
# D_76           float64
# B_24           float64
# R_7            float64
# D_77           float64
# B_25           float64
# B_26           float64
# D_78           float64
# D_79           float64
# R_8            float64
# R_9            float64
# S_16           float64
# D_80           float64
# R_10           float64
# R_11           float64
# B_27           float64
# D_81           float64
# D_82           float64
# S_17           float64
# R_12           float64
# B_28           float64
# R_13           float64
# D_83           float64
# R_14           float64
# R_15           float64
# D_84           float64
# R_16           float64
# B_29           float64
# B_30           float64
# S_18           float64
# D_86           float64
# D_87           float64
# R_17           float64
# R_18           float64
# D_88           float64
# B_31             int64
# S_19           float64
# R_19           float64
# B_32           float64
# S_20           float64
# R_20           float64
# R_21           float64
# B_33           float64
# D_89           float64
# R_22           float64
# R_23           float64
# D_91           float64
# D_92           float64
# D_93           float64
# D_94           float64
# R_24           float64
# R_25           float64
# D_96           float64
# S_22           float64
# S_23           float64
# S_24           float64
# S_25           float64
# S_26           float64
# D_102          float64
# D_103          float64
# D_104          float64
# D_105          float64
# D_106          float64
# D_107          float64
# B_36           float64
# B_37           float64
# R_26           float64
# R_27           float64
# B_38           float64
# D_108          float64
# D_109          float64
# D_110          float64
# D_111          float64
# B_39           float64
# D_112          float64
# B_40           float64
# S_27           float64
# D_113          float64
# D_114          float64
# D_115          float64
# D_116          float64
# D_117          float64
# D_118          float64
# D_119          float64
# D_120          float64
# D_121          float64
# D_122          float64
# D_123          float64
# D_124          float64
# D_125          float64
# D_126          float64
# D_127          float64
# D_128          float64
# D_129          float64
# B_41           float64
# B_42           float64
# D_130          float64
# D_131          float64
# D_132          float64
# D_133          float64
# R_28           float64
# D_134          float64
# D_135          float64
# D_136          float64
# D_137          float64
# D_138          float64
# D_139          float64
# D_140          float64
# D_141          float64
# D_142          float64
# D_143          float64
# D_144          float64
# D_145          float64
# dtype: object

# %%
payer_small.to_parquet('payer_small_uncompressed.parquet')

# %% [markdown]
# ## Downloading chunks from bigquery

# %%
#key_path = "/Users/isislim/Documents/LeWagon/project_pitch/amex-data-a1386be8bf58.json"

# %%
#credentials = service_account.Credentials.from_service_account_file(
#     key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
# )

# %%
#client = bigquery.Client(credentials=credentials)

# %%
# return a chunk of bigquery dataset
def get_bq_chunk(table: str,
                 index: int,
                 chunk_size: int) -> pd.DataFrame:
    
    project_name = 'amex-data'
    dataset_name = 'train_data'
    
    key_path = "/Users/isislim/Documents/LeWagon/project_pitch/amex-data-a1386be8bf58.json"
    credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"])
    
    table = f"{project_name}.{dataset_name}.{table}"
    client = bigquery.Client(credentials=credentials)
    rows = client.list_rows(table, start_index=index, max_results=chunk_size)
    df = rows.to_dataframe()

    return df

# %%
get_bq_chunk("train_data", 0, 10000)
# Out:
#                                           customer_ID         S_2  P_2  \
# 0   009b4f146ac20c9e528e23137b3fbef84856f327124ade...  2017-11-06  NaN
# 1   00b686ade48123a567b066546d791c825ddd735b1bbd9c...  2017-03-09  NaN
# 2   00fa02b4d245e7337cd6bcf0752f3d2d4a46356feb8437...  2017-08-23  NaN
# 3   011d531f608afddd758bce447bcba8e5e3044aa3324b21...  2018-02-01  NaN
# 4   014c11f3aa783e11b9ef3c7ae3243cf975e3ae868d5bff...  2017-11-28  NaN
# 5   0178456d1d5d9fbfa73bf2849207a34514aad5b8b39ff0...  2017-08-09  NaN
# 6   01ba4472c1120f57cfebc0cd97530b382d2e0a3cb75811...  2017-03-27  NaN
# 7   01ebf0b6e9b1512af9542ce8e5bc951bdc9f459cda268d...  2018-01-31  NaN
# 8   01feaa56f2d85c7e8205a69cb4a251f5648d980feb082f...  2017-09-30  NaN
# 9   02094db39fd939741345f0b303d9e30649dd03e32b7e5c...  2017-04-20  NaN
# 10  020b55f7469e4e7fcb53886763fc2d0f3eafb01d9f0b7f...  2017-08-03  NaN
# 11  021277ca8f49cf98b0e5385a4df9471adc961480e9d4c6...  2017-08-18  NaN
# 12  023ca33b3d36b52bd9fa813e52cdfad19d6e5a543df7bc...  2017-04-20  NaN
# 13  024fea7058a83b531ec7f876e2b56408960aa1c4790d7b...  2017-08-09  NaN
# 14  02a87fe55abe6c80e26e23dbce50d442c9a68c6ec85115...  2017-08-12  NaN
# 15  02d4492321a142e3b584c3b89298ef90adf41a0a59d1a4...  2017-10-14  NaN
# 16  02fc6b990f9df0a55cda6ed8437c1ca4f984f0b18b795e...  2017-11-19  NaN
# 17  0312833aed7a6223d11a75149fc319a0e747d3909aaa92...  2017-08-10  NaN
# 18  03152c20fb0da4b69d111df3411b33f70a78f9a9d46a44...  2017-09-30  NaN
# 19  031dcc8030eb6d2abd02737e4cf4a98122a491a27011d9...  2017-06-08  NaN
#
#         D_39       B_1  B_2       R_1       S_3  D_41  B_3  ...  D_136  D_137  \
# 0   0.003119  0.263537  NaN  0.007732  0.221343   NaN  NaN  ...    NaN    NaN
# 1   0.001309  1.322240  NaN  0.009585  0.172960   NaN  NaN  ...    NaN    NaN
# 2   0.009662  0.056115  NaN  0.003734  0.173021   NaN  NaN  ...    NaN    NaN
# 3   0.005666  0.004427  NaN  0.008111  0.198681   NaN  NaN  ...    NaN    NaN
# 4   0.007519  0.154334  NaN  0.004032  0.215892   NaN  NaN  ...    NaN    NaN
# 5   0.008415  0.045750  NaN  0.003822  0.169228   NaN  NaN  ...    NaN    NaN
# 6   0.000824  1.041876  NaN  0.005455  0.173671   NaN  NaN  ...    NaN    NaN
# 7   0.008873  0.663521  NaN  0.007629  0.335802   NaN  NaN  ...    NaN    NaN
# 8   0.002359  0.102399  NaN  0.009046  0.177288   NaN  NaN  ...    NaN    NaN
# 9   0.008395  0.308957  NaN  0.007148  0.165002   NaN  NaN  ...    NaN    NaN
# 10  0.009881  1.114417  NaN  0.008224  0.217266   NaN  NaN  ...    NaN    NaN
# 11  0.003940  0.017111  NaN  0.009707  0.175295   NaN  NaN  ...    NaN    NaN
# 12  0.004829  0.384615  NaN  0.001631  0.178010   NaN  NaN  ...    NaN    NaN
# 13  0.005685  0.100499  NaN  0.005114  0.217893   NaN  NaN  ...    NaN    NaN
# 14  0.006923  1.319146  NaN  0.006677  0.172258   NaN  NaN  ...    NaN    NaN
# 15  0.006120  0.499256  NaN  0.005600  0.229239   NaN  NaN  ...    NaN    NaN
# 16  0.007434  0.027394  NaN  0.004056  0.224049   NaN  NaN  ...    NaN    NaN
# 17  0.008989  0.104484  NaN  0.001323  0.372879   NaN  NaN  ...    NaN    NaN
# 18  0.007043  0.117348  NaN  0.000824  0.175777   NaN  NaN  ...    NaN    NaN
# 19  0.005830  0.184807  NaN  0.000879  0.185621   NaN  NaN  ...    NaN    NaN
#
#     D_138  D_139     D_140  D_141  D_142  D_143     D_144  D_145
# 0     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 1     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 2     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 3     NaN    NaN  0.005793    NaN    NaN    NaN  0.000278    NaN
# 4     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 5     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 6     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 7     NaN    NaN  0.008086    NaN    NaN    NaN  0.002548    NaN
# 8     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 9     NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 10    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 11    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 12    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 13    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 14    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 15    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 16    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 17    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 18    NaN    NaN       NaN    NaN    NaN    NaN       NaN    NaN
# 19    NaN    NaN  0.003441    NaN    NaN    NaN  0.007686    NaN
#
# [20 rows x 190 columns]

# %%
# convert dtypes to smaller size
def numeric_conversion(df):
    input_size = df.memory_usage(index=True).sum()/ 1024
    print("new dataframe size: ", round(input_size,2), 'kB')
    
    in_size = df.memory_usage(index=True).sum()
    
    for type in ["float", "integer"]:
        l_cols = list(df.select_dtypes(include=type))
        for col in l_cols:
            df[col] = pd.to_numeric(df[col], downcast=type)
    out_size = df.memory_usage(index=True).sum()
    ratio = (1 - round(out_size / in_size, 2)) * 100
    
    print("optimized size by {} %".format(round(ratio,2)))
    print("new dataframe size: ", round(out_size / 1024,2), " kB")

    return df

# %%
test_df = numeric_conversion(get_bq_chunk("train_data", 0, 10000))
# Out:
# new dataframe size:  14843.88 kB
# optimized size by 49.0 %
# new dataframe size:  7548.95  kB

# %%
# save converted chunks to bigquery
def save_bq_chunk(table: str,
                  data: pd.DataFrame,
                  is_first: bool):
   
    project_name = 'amex-data'
    dataset_name = 'train_data'

    table = f"{project_name}.{dataset_name}.{table}"

    data.columns = [f"_{column}" if type(column) != str else column for column in data.columns]

    key_path = "/Users/isislim/Documents/LeWagon/project_pitch/amex-data-a1386be8bf58.json"
    credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"])
    
    client = bigquery.Client(credentials=credentials)

    write_mode = "WRITE_TRUNCATE" if is_first else "WRITE_APPEND"
    job_config = bigquery.LoadJobConfig(write_disposition=write_mode)

    job = client.load_table_from_dataframe(data,table,job_config=job_config)
    result = job.result()

# %%
save_bq_chunk("train_data", test_df, is_first=True)
# Out:
# /Users/isislim/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/_pandas_helpers.py:470: UserWarning: Pyarrow could not determine the type of columns: D_64.
#   warnings.warn(

# %%
test_df_uncompressed = get_bq_chunk("train_data", 0, 10000)

# %%
def save_local_chunk(data: pd.DataFrame,
                     is_first: bool):
    """
    save a chunk of the dataset to local disk
    """

    path = '/Users/isislim/Documents/LeWagon/project_pitch/train_data_processed.parquet'

    print(Fore.BLUE + f"\nSave data to {path}:" + Style.RESET_ALL)

    data.to_parquet(path)

# %%
save_local_chunk(test_df,is_first=True)
# Out:
# Save data to /Users/isislim/Documents/LeWagon/project_pitch/train_data_processed.parquet:

# %%
from colorama import Fore, Style

# %%
def compress():

    # iterate on the dataset, by chunks
    chunk_size = 100000
    chunk_id = 0
    row_count = 0
    source_name = "train_data"
    destination_name = f"{source_name}_processed"

    while (True):
        
        print(Fore.BLUE + f"\nProcessing chunk n°{chunk_id}..." + Style.RESET_ALL)

        data_chunk = get_bq_chunk(source_name,
                                  index=chunk_id * chunk_size,
                                  chunk_size=chunk_size)

        # Break out of while loop if data is none
        if data_chunk is None:
            print(Fore.BLUE + "\nNo data in latest chunk..." + Style.RESET_ALL)
            break

        row_count += data_chunk.shape[0]

        data_chunk_compressed = numeric_conversion(data_chunk)

        # save and append the chunk
        is_first = chunk_id == 0

        save_local_chunk(data=data_chunk_compressed,
                      is_first=is_first)

        chunk_id += 1
        
    if row_count == 0:
        print("\n✅ no new data for processing 👌")
        return None

    print(f"\n✅ data processed saved entirely: {row_count} rows processed")

    return None

# %%
compress()
# Out:
# Processing chunk n°0...
#
# Processing chunk n°1...
#
# Processing chunk n°2...
#
# Processing chunk n°3...
#
# Processing chunk n°4...
#
# Processing chunk n°5...
#
# Processing chunk n°6...
#
# Processing chunk n°7...
#
# Processing chunk n°8...
#
# Processing chunk n°9...
#
# Processing chunk n°10...
#
# Processing chunk n°11...
#
# Processing chunk n°12...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 compress()
#
# Input In [21], in compress()
#      10 while (True):
#      12     print(Fore.BLUE + f"\nProcessing chunk n°{chunk_id}..." + Style.RESET_ALL)
# ---> 14     data_chunk = get_bq_chunk(source_name,
#      15                               index=chunk_id * chunk_size,
#      16                               chunk_size=chunk_size)
#      18     # Break out of while loop if data is none
#      19     if data_chunk is None:
#
# Input In [9], in get_bq_chunk(table, index, chunk_size)
#      14 client = bigquery.Client(credentials=credentials)
#      15 rows = client.list_rows(table, start_index=index, max_results=chunk_size)
# ---> 16 df = rows.to_dataframe()
#      18 return df
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1985, in RowIterator.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, geography_as_object)
#    1982     create_bqstorage_client = False
#    1983     bqstorage_client = None
# -> 1985 record_batch = self.to_arrow(
#    1986     progress_bar_type=progress_bar_type,
#    1987     bqstorage_client=bqstorage_client,
#    1988     create_bqstorage_client=create_bqstorage_client,
#    1989 )
#    1991 # When converting timestamp values to nanosecond precision, the result
#    1992 # can be out of pyarrow bounds. To avoid the error when converting to
#    1993 # Pandas, we set the timestamp_as_object parameter to True, if necessary.
#    1994 types_to_check = {
#    1995     pyarrow.timestamp("us"),
#    1996     pyarrow.timestamp("us", tz=datetime.timezone.utc),
#    1997 }
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1779, in RowIterator.to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1774 progress_bar = get_progress_bar(
#    1775     progress_bar_type, "Downloading", self.total_rows, "rows"
#    1776 )
#    1778 record_batches = []
# -> 1779 for record_batch in self.to_arrow_iterable(
#    1780     bqstorage_client=bqstorage_client
#    1781 ):
#    1782     record_batches.append(record_batch)
#    1784     if progress_bar is not None:
#    1785         # In some cases, the number of total rows is not populated
#    1786         # until the first page of rows is fetched. Update the
#    1787         # progress bar's total to keep an accurate count.
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1635, in RowIterator._to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1628     bqstorage_client = None
#    1630 result_pages = (
#    1631     bqstorage_download()
#    1632     if bqstorage_client is not None
#    1633     else tabledata_list_download()
#    1634 )
# -> 1635 yield from result_pages
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/_pandas_helpers.py:630, in download_arrow_row_iterator(pages, bq_schema)
#     627 column_names = bq_to_arrow_schema(bq_schema) or [field.name for field in bq_schema]
#     628 arrow_types = [bq_to_arrow_data_type(field) for field in bq_schema]
# --> 630 for page in pages:
#     631     yield _row_iterator_page_to_arrow(page, column_names, arrow_types)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/page_iterator.py:250, in Iterator._page_iter(self, increment)
#     248     self.num_results += page.num_items
#     249 yield page
# --> 250 page = self._next_page()
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/page_iterator.py:373, in HTTPIterator._next_page(self)
#     366 """Get the next page in the iterator.
#     367
#     368 Returns:
#     369     Optional[Page]: The next page in the iterator or :data:`None` if
#     370         there are no pages left.
#     371 """
#     372 if self._has_next_page():
# --> 373     response = self._get_next_page_response()
#     374     items = response.get(self._items_key, ())
#     375     page = Page(self, items, self.item_to_value, raw_page=response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1589, in RowIterator._get_next_page_response(self)
#    1587         del params["startIndex"]
#    1588     params["maxResults"] = self._page_size
# -> 1589 return self.api_request(
#    1590     method=self._HTTP_METHOD, path=self.path, query_params=params
#    1591 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/client.py:784, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     779     with create_span(
#     780         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     781     ):
#     782         return call()
# --> 784 return call()
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     279 target = functools.partial(func, *args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188 for sleep in sleep_generator:
#     189     try:
# --> 190         return target()
#     192     # pylint: disable=broad-except
#     193     # This function explicitly must deal with broad exceptions.
#     194     except Exception as exc:
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/auth/transport/requests.py:549, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     546 remaining_time = guard.remaining_timeout
#     548 with TimeoutGuard(remaining_time) as guard:
# --> 549     response = super(AuthorizedSession, self).request(
#     550         method,
#     551         url,
#     552         data=data,
#     553         headers=request_headers,
#     554         timeout=timeout,
#     555         **kwargs
#     556     )
#     557 remaining_time = guard.remaining_timeout
#     559 # If the response indicated that the credentials needed to be
#     560 # refreshed, then refresh the credentials and re-attempt the
#     561 # request.
#     562 # A stored token may expire between the time it is retrieved and
#     563 # the time the request is made, so we may need to try twice.
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
compress()
# Out:
# Processing chunk n°0...
#
# Save data to /Users/isislim/Documents/LeWagon/project_pitch/train_data_processed.csv:
#
# Processing chunk n°1...
#
# Save data to /Users/isislim/Documents/LeWagon/project_pitch/train_data_processed.csv:
#
# Processing chunk n°2...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 compress()
#
# Input In [25], in compress()
#      10 while (True):
#      12     print(Fore.BLUE + f"\nProcessing chunk n°{chunk_id}..." + Style.RESET_ALL)
# ---> 14     data_chunk = get_bq_chunk(source_name,
#      15                               index=chunk_id * chunk_size,
#      16                               chunk_size=chunk_size)
#      18     # Break out of while loop if data is none
#      19     if data_chunk is None:
#
# Input In [9], in get_bq_chunk(table, index, chunk_size)
#      14 client = bigquery.Client(credentials=credentials)
#      15 rows = client.list_rows(table, start_index=index, max_results=chunk_size)
# ---> 16 df = rows.to_dataframe()
#      18 return df
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1985, in RowIterator.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, geography_as_object)
#    1982     create_bqstorage_client = False
#    1983     bqstorage_client = None
# -> 1985 record_batch = self.to_arrow(
#    1986     progress_bar_type=progress_bar_type,
#    1987     bqstorage_client=bqstorage_client,
#    1988     create_bqstorage_client=create_bqstorage_client,
#    1989 )
#    1991 # When converting timestamp values to nanosecond precision, the result
#    1992 # can be out of pyarrow bounds. To avoid the error when converting to
#    1993 # Pandas, we set the timestamp_as_object parameter to True, if necessary.
#    1994 types_to_check = {
#    1995     pyarrow.timestamp("us"),
#    1996     pyarrow.timestamp("us", tz=datetime.timezone.utc),
#    1997 }
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1779, in RowIterator.to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1774 progress_bar = get_progress_bar(
#    1775     progress_bar_type, "Downloading", self.total_rows, "rows"
#    1776 )
#    1778 record_batches = []
# -> 1779 for record_batch in self.to_arrow_iterable(
#    1780     bqstorage_client=bqstorage_client
#    1781 ):
#    1782     record_batches.append(record_batch)
#    1784     if progress_bar is not None:
#    1785         # In some cases, the number of total rows is not populated
#    1786         # until the first page of rows is fetched. Update the
#    1787         # progress bar's total to keep an accurate count.
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1635, in RowIterator._to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1628     bqstorage_client = None
#    1630 result_pages = (
#    1631     bqstorage_download()
#    1632     if bqstorage_client is not None
#    1633     else tabledata_list_download()
#    1634 )
# -> 1635 yield from result_pages
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/_pandas_helpers.py:630, in download_arrow_row_iterator(pages, bq_schema)
#     627 column_names = bq_to_arrow_schema(bq_schema) or [field.name for field in bq_schema]
#     628 arrow_types = [bq_to_arrow_data_type(field) for field in bq_schema]
# --> 630 for page in pages:
#     631     yield _row_iterator_page_to_arrow(page, column_names, arrow_types)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/page_iterator.py:250, in Iterator._page_iter(self, increment)
#     248     self.num_results += page.num_items
#     249 yield page
# --> 250 page = self._next_page()
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/page_iterator.py:373, in HTTPIterator._next_page(self)
#     366 """Get the next page in the iterator.
#     367
#     368 Returns:
#     369     Optional[Page]: The next page in the iterator or :data:`None` if
#     370         there are no pages left.
#     371 """
#     372 if self._has_next_page():
# --> 373     response = self._get_next_page_response()
#     374     items = response.get(self._items_key, ())
#     375     page = Page(self, items, self.item_to_value, raw_page=response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1589, in RowIterator._get_next_page_response(self)
#    1587         del params["startIndex"]
#    1588     params["maxResults"] = self._page_size
# -> 1589 return self.api_request(
#    1590     method=self._HTTP_METHOD, path=self.path, query_params=params
#    1591 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/client.py:784, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     779     with create_span(
#     780         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     781     ):
#     782         return call()
# --> 784 return call()
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     279 target = functools.partial(func, *args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188 for sleep in sleep_generator:
#     189     try:
# --> 190         return target()
#     192     # pylint: disable=broad-except
#     193     # This function explicitly must deal with broad exceptions.
#     194     except Exception as exc:
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/auth/transport/requests.py:549, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     546 remaining_time = guard.remaining_timeout
#     548 with TimeoutGuard(remaining_time) as guard:
# --> 549     response = super(AuthorizedSession, self).request(
#     550         method,
#     551         url,
#     552         data=data,
#     553         headers=request_headers,
#     554         timeout=timeout,
#     555         **kwargs
#     556     )
#     557 remaining_time = guard.remaining_timeout
#     559 # If the response indicated that the credentials needed to be
#     560 # refreshed, then refresh the credentials and re-attempt the
#     561 # request.
#     562 # A stored token may expire between the time it is retrieved and
#     563 # the time the request is made, so we may need to try twice.
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def compress_test():
        
    print(Fore.BLUE + f"\nProcessing chunk n°0..." + Style.RESET_ALL)
    
    source_name = "train_data"

    data_chunk = get_bq_chunk(source_name, index=0,chunk_size=10000)

    data_chunk_compressed = numeric_conversion(data_chunk)

    # save and append the chunk

    save_local_chunk(data=data_chunk_compressed,
                      is_first=True)

    print(f"\n✅ data processed saved entirely")

    return None

# %%
compress_test()
# Out:
# Processing chunk n°0...
# new dataframe size:  14843.88 kB
# optimized size by 49.0 %
# new dataframe size:  7548.95  kB
#
# Save data to /Users/isislim/Documents/LeWagon/project_pitch/train_data_processed.csv:
#
# ✅ data processed saved entirely

# %% [markdown]
# ## Method from kaggle https://www.kaggle.com/code/ishaan45/reduce-file-size-csv-to-parquet

# %%
cat_df = get_bq_chunk("train_data", 0, 10000)

# %%
def get_col_dtypes(data):
    col_dtypes = {}
    for col in data.columns:
        if str(data[col].dtype) == 'float64':
            col_dtypes[col] = 'float32'
        elif str(data[col].dtype) == 'int64':
            col_dtypes[col] = 'int32'
        elif str(data[col].dtype) == 'object':
            col_dtypes[col] = 'category'
        else:
            col_dtypes[col] = str(data[col].dtype)
    return col_dtypes

# %%
col_dtypes = get_col_dtypes(cat_df)

# %%
# def write_parquet(path, save_loc, col_dtypes, chunk_size=10000):
#     schema = ''
#     writer = ''
#     for i,chunk in enumerate(pd.read_csv(path, dtype=col_dtypes, iterator=True, chunksize=10000)):
#         if i == 0:
#             schema = pa.Table.from_pandas(df=chunk).schema
#             writer = pq.ParquetWriter(save_loc, schema, compression='snappy')
#         table = pa.Table.from_pandas(chunk, schema=schema)
#         writer.write_table(table)
#     return None

# %%
import pyarrow as pa
import pyarrow.parquet as pq
import time

# %%
def save_local_chunk(data: pd.DataFrame, save_loc, writer=None):
    """
    save chunks of the dataset to local disk in parquet format
    """

    table = pa.Table.from_pandas(data)
    
    if writer is None:
        writer = pq.ParquetWriter(save_loc, table.schema)
        
    writer.write_table(table=table)
    
    return writer

# %%
cat_df

# %%
save_loc = '/Users/isislim/Documents/LeWagon/project_pitch/small_train_data_processed.parquet'

# %%
schema = pa.Table.from_pandas(df=cat_df).schema
writer = pq.ParquetWriter(save_loc, schema, compression='snappy')
table = pa.Table.from_pandas(cat_df, schema=schema)
writer.write_table(table)
writer.close()

# %%
def compress():

    # iterate on the dataset, by chunks
    chunk_size = 1000
    chunk_id = 0
    row_count = 0
    source_name = "defaulter_1percent"

    while (True):
        
        print(Fore.BLUE + f"\nProcessing chunk n°{chunk_id}..." + Style.RESET_ALL)

        data_chunk = get_bq_chunk(source_name,
                                  index=chunk_id * chunk_size,
                                  chunk_size=chunk_size)

        # Break out of while loop if data is none
        if data_chunk is None:
            print(Fore.BLUE + "\nNo data in latest chunk..." + Style.RESET_ALL)
            break

        row_count += data_chunk.shape[0]

        data_chunk_compressed = numeric_conversion(data_chunk)

        # save and append the chunk
        is_first = chunk_id == 0

        save_local_chunk(data=data_chunk_compressed)

        chunk_id += 1
        
    if row_count == 0:
        print("\n✅ no new data for processing 👌")
        return None

    print(f"\n✅ data processed saved entirely: {row_count} rows processed")

    return None

# %%
compress()
# Out:
# Processing chunk n°0...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°1...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°2...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°3...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°4...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°5...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°6...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°7...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°8...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°9...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°10...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°11...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°12...
# new dataframe size:  1492.31 kB
# optimized size by 49.0 %
# new dataframe size:  756.96  kB
#
# Processing chunk n°13...
# new dataframe size:  492.55 kB
# optimized size by 49.0 %
# new dataframe size:  249.88  kB
#
# Processing chunk n°14...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°15...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°16...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°17...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°18...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°19...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°20...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°21...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°22...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°23...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°24...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°25...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°26...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°27...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°28...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°29...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°30...
# new dataframe size:  0.12 kB
# optimized size by 0.0 %
# new dataframe size:  0.12  kB
#
# Processing chunk n°31...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [143], in <cell line: 1>()
# ----> 1 compress()
#
# Input In [142], in compress()
#       9 while (True):
#      11     print(Fore.BLUE + f"\nProcessing chunk n°{chunk_id}..." + Style.RESET_ALL)
# ---> 13     data_chunk = get_bq_chunk(source_name,
#      14                               index=chunk_id * chunk_size,
#      15                               chunk_size=chunk_size)
#      17     # Break out of while loop if data is none
#      18     if data_chunk is None:
#
# Input In [9], in get_bq_chunk(table, index, chunk_size)
#      13 table = f"{project_name}.{dataset_name}.{table}"
#      14 client = bigquery.Client(credentials=credentials)
# ---> 15 rows = client.list_rows(table, start_index=index, max_results=chunk_size)
#      16 df = rows.to_dataframe()
#      18 return df
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/client.py:3790, in Client.list_rows(self, table, selected_fields, max_results, page_token, start_index, page_size, retry, timeout)
#    3787 # No schema, but no selected_fields. Assume the developer wants all
#    3788 # columns, so get the table resource for them rather than failing.
#    3789 elif len(schema) == 0:
# -> 3790     table = self.get_table(table.reference, retry=retry, timeout=timeout)
#    3791     schema = table.schema
#    3793 params: Dict[str, Any] = {}
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/client.py:1034, in Client.get_table(self, table, retry, timeout)
#    1032 path = table_ref.path
#    1033 span_attributes = {"path": path}
# -> 1034 api_response = self._call_api(
#    1035     retry,
#    1036     span_name="BigQuery.getTable",
#    1037     span_attributes=span_attributes,
#    1038     method="GET",
#    1039     path=path,
#    1040     timeout=timeout,
#    1041 )
#    1042 return Table.from_api_repr(api_response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/bigquery/client.py:782, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     778 if span_name is not None:
#     779     with create_span(
#     780         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     781     ):
# --> 782         return call()
#     784 return call()
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     279 target = functools.partial(func, *args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188 for sleep in sleep_generator:
#     189     try:
# --> 190         return target()
#     192     # pylint: disable=broad-except
#     193     # This function explicitly must deal with broad exceptions.
#     194     except Exception as exc:
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/google/auth/transport/requests.py:549, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     546 remaining_time = guard.remaining_timeout
#     548 with TimeoutGuard(remaining_time) as guard:
# --> 549     response = super(AuthorizedSession, self).request(
#     550         method,
#     551         url,
#     552         data=data,
#     553         headers=request_headers,
#     554         timeout=timeout,
#     555         **kwargs
#     556     )
#     557 remaining_time = guard.remaining_timeout
#     559 # If the response indicated that the credentials needed to be
#     560 # refreshed, then refresh the credentials and re-attempt the
#     561 # request.
#     562 # A stored token may expire between the time it is retrieved and
#     563 # the time the request is made, so we may need to try twice.
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.8.12/envs/AMEX_default_prediction/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
pd.read_parquet('/Users/isislim/Documents/LeWagon/project_pitch/small_train_data_processed.parquet')
# Out:
# Empty DataFrame
# Columns: [int64_field_0, customer_ID, S_2, P_2, D_39, B_1, B_2, R_1, S_3, D_41, B_3, D_42, D_43, D_44, B_4, D_45, B_5, R_2, D_46, D_47, D_48, D_49, B_6, B_7, B_8, D_50, D_51, B_9, R_3, D_52, P_3, B_10, D_53, S_5, B_11, S_6, D_54, R_4, S_7, B_12, S_8, D_55, D_56, B_13, R_5, D_58, S_9, B_14, D_59, D_60, D_61, B_15, S_11, D_62, D_63, D_64, D_65, B_16, B_17, B_18, B_19, D_66, B_20, D_68, S_12, R_6, S_13, B_21, D_69, B_22, D_70, D_71, D_72, S_15, B_23, D_73, P_4, D_74, D_75, D_76, B_24, R_7, D_77, B_25, B_26, D_78, D_79, R_8, R_9, S_16, D_80, R_10, R_11, B_27, D_81, D_82, S_17, R_12, B_28, R_13, ...]
# Index: []
#
# [0 rows x 191 columns]

# %%
table = pa.Table.from_pandas(cat_df)
writer = pq.ParquetWriter(save_loc, table.schema)

# %%
writer
